# %%
pwd
# Out:
# '/content'

# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

mnist = np.loadtxt('/content/sample_data/mnist_train_small.csv', delimiter=',', dtype=np.float32)

# %%
x_train = mnist[:,1:]
t_train = mnist[:,:1]

image = x_train[0].reshape(28, 28)
plt.imshow(image, cmap='gray')
plt.show()
print(t_train.shape)
# Out:
# (20000, 1)
